# %% [markdown]
# ## Enron Email Classification using Word Embeddings and LSTM
#
# you can find pre-processing of 'preprocessed.csv' for machine learning classifiers at:
#
# [https://www.kaggle.com/ankur561999/enron-email-classification-using-machine-learning](https://www.kaggle.com/ankur561999/enron-email-classification-using-machine-learning)
#
# and data cleaning of enron email dataset at:
#
# [https://www.kaggle.com/ankur561999/data-cleaning-enron-email-dataset](https://www.kaggle.com/ankur561999/data-cleaning-enron-email-dataset)

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk(os.getcwd()+'/Enron Dataset'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/.DS_Store
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/3210.2001-10-19.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/0258.2001-03-19.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/2582.2001-09-18.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/1193.2001-06-14.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/4902.2005-06-19.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/0293.2001-03-21.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/1891.2001-08-03.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/1344.2001-06-27.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/0992.2004-10-19.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/3406.2001-10-25.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/1063.2001-05-23.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/0246.2004-08-27.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/5466.2002-02-04.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/2794.2001-09-28.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/5512.2002-02-06.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/3922.2001-11-12.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/1898.2001-08-06.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/1797.2004-12-10.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/3366.2001-10-24.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/2650.2005-01-23.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/2872.2001-10-02.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/2483.2001-09-13.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/2728.2001-09-26.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/1976.2004-12-22.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/3218.2001-10-20.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/4023.2005-04-18.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/0324.2001-03-22.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/2074.2004-12-26.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/0227.2001-03-16.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/5336.2005-07-16.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/2904.2001-10-02.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/3173.2001-10-17.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/4320.2001-11-29.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/0980.2001-05-11.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/5269.2002-01-25.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/1230.2001-06-18.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/3875.2001-11-09.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/5340.2002-01-30.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/0131.2004-08-12.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/2440.2001-09-12.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/4229.2001-11-26.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/5287.2005-07-13.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/1017.2001-05-16.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/4383.2005-05-11.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/4993.2005-06-26.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/5415.2005-07-22.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/4295.2001-11-28.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/1925.2004-12-18.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/1953.2001-08-09.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/1801.2001-07-27.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/4733.2005-06-07.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/1565.2001-07-13.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/3500.2001-10-29.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/2530.2001-09-14.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/3899.2001-11-11.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/5170.2002-01-21.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/4299.2001-11-28.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/0537.2001-04-06.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/2908.2001-10-02.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/1851.2001-07-31.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/0911.2001-05-04.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/0815.2004-10-09.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/0018.2004-08-03.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/1564.2001-07-12.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/2692.2001-09-24.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/4380.2001-12-02.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/3879.2001-11-09.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/2531.2001-09-15.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/4770.2002-01-02.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/0800.2001-04-27.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/2211.2005-01-02.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/2798.2001-09-28.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/0232.2004-08-24.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/0449.2001-04-02.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/5104.2002-01-14.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/4497.2001-12-08.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/1290.2004-11-09.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/4740.2001-12-31.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/4132.2001-11-20.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/1921.2001-08-07.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/0548.2001-04-09.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/4030.2001-11-15.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/0072.2001-02-26.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/1221.2004-11-06.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/4806.2002-01-02.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/3806.2001-11-06.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/2522.2005-01-19.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/3014.2001-10-09.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/2209.2001-08-31.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/5187.2002-01-21.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/0648.2001-04-17.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/3638.2001-11-01.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/1674.2004-12-02.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/4723.2005-06-06.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/0501.2001-04-05.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/0261.2001-03-19.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/1914.2001-08-07.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/2937.2001-10-04.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/4004.2001-11-14.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/4193.2005-04-30.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/4377.2001-12-02.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/4654.2001-12-20.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/4033.2005-04-19.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/2887.2005-02-02.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/4832.2002-01-03.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/3832.2001-11-07.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/2889.2001-10-02.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/0084.2001-02-27.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/0740.2001-04-24.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/2478.2001-09-13.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/4535.2001-12-11.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/2989.2001-10-08.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/2740.2005-01-28.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/1244.2004-11-07.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/4319.2001-11-29.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/0269.2001-03-20.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/0780.2001-04-26.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/0924.2001-05-04.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/4787.2002-01-02.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/1705.2004-12-04.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/0958.2001-05-08.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/5133.2002-01-16.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/1418.2004-11-17.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/4627.2005-05-28.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/4648.2005-05-29.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/3370.2005-03-01.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/3219.2005-02-19.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/2712.2001-09-25.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/5238.2005-07-10.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/2848.2001-10-01.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/0428.2001-03-30.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/3037.2001-10-10.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/2579.2001-09-18.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/5251.2002-01-24.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/3746.2001-11-05.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/2505.2001-09-14.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/3535.2001-10-29.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/4103.2001-11-19.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/2844.2001-10-01.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/0036.2001-02-16.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/2699.2005-01-25.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/2635.2005-01-22.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/4314.2001-11-28.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/1022.2001-05-16.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/2112.2004-12-28.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/3539.2001-10-29.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/2509.2001-09-14.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/2474.2001-09-13.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/4940.2002-01-07.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/0127.2001-03-08.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/4410.2001-12-04.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/2885.2001-10-02.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/1054.2001-05-21.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/3146.2001-10-17.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/5083.2002-01-12.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/1023.2001-05-17.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/4692.2001-12-24.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/0212.2001-03-16.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/0928.2001-05-04.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/3126.2005-02-14.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/0311.2001-03-22.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/0265.2001-03-20.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/0954.2001-05-08.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/5043.2002-01-10.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/4660.2005-05-31.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/4008.2001-11-14.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/3882.2001-11-09.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/0837.2004-10-11.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/4389.2005-05-11.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/3353.2001-10-24.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/3917.2001-11-12.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/4622.2005-05-27.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/5453.2002-02-04.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/4739.2005-06-07.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/1476.2001-07-05.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/1940.2004-12-19.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/1503.2001-07-06.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/2205.2001-08-31.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/1057.2001-05-22.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/3018.2001-10-09.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/3634.2001-11-01.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/0644.2001-04-17.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/0471.2001-04-03.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/3732.2005-03-25.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/2660.2001-09-21.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/1918.2001-08-07.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/3606.2001-10-31.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/1741.2001-07-24.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/3673.2005-03-20.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/2123.2004-12-28.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/4679.2005-06-01.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/0061.2001-02-23.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/2595.2001-09-19.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/3934.2001-11-12.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/1873.2004-12-15.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/2782.2001-09-28.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/5504.2002-02-06.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/1003.2001-05-14.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/3410.2001-10-25.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/0424.2001-03-29.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/3617.2001-11-01.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/0285.2001-03-21.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/1887.2001-08-03.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/1352.2001-06-27.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/1118.2001-06-01.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/1966.2001-08-10.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/1494.2001-07-06.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/4706.2001-12-27.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/3371.2001-10-25.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/2643.2001-09-21.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/0900.2001-05-03.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/5061.2002-01-11.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/1817.2001-07-27.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/4120.2001-11-19.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/1945.2001-08-09.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/4545.2005-05-21.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/0333.2001-03-23.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/1103.2004-10-28.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/2913.2001-10-03.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/0798.2004-10-07.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/4094.2001-11-19.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/3769.2001-11-05.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/3862.2001-11-08.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/3260.2005-02-21.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/4432.2001-12-05.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/2688.2001-09-24.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/3165.2001-10-17.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/4336.2001-11-29.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/1270.2004-11-08.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/0996.2001-05-11.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/3781.2005-03-30.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/0877.2001-05-02.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/1002.2004-10-21.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/5362.2005-07-17.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/4712.2005-06-06.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/1182.2001-06-13.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/2673.2005-01-24.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/4609.2005-05-26.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/3169.2001-10-17.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/5273.2002-01-25.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/0500.2004-09-17.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/1847.2001-07-31.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/0521.2001-04-06.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/3654.2005-03-19.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/4098.2001-11-19.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/4397.2001-12-03.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/2247.2005-01-05.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/4233.2001-11-26.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/2526.2001-09-14.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/3765.2001-11-05.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/3380.2005-03-01.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/0496.2001-04-05.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/5054.2005-06-28.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/4810.2002-01-02.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/4676.2001-12-21.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/1498.2001-07-06.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/4601.2001-12-17.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/4363.2005-05-10.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/5267.2005-07-12.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/4026.2001-11-15.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/2732.2001-09-26.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/2868.2001-10-02.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/2599.2001-09-19.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/2877.2005-02-02.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/3938.2001-11-12.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/5508.2002-02-06.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/1459.2001-07-05.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/4762.2005-06-09.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/4766.2002-01-02.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/3811.2001-11-07.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/0692.2004-09-30.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/5449.2002-02-04.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/4824.2002-01-03.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/3235.2001-10-22.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/3349.2001-10-24.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/4344.2005-05-07.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/1084.2001-05-25.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/1903.2001-08-06.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/0058.2001-02-23.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/5116.2005-07-03.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/2222.2005-01-04.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/0029.2004-08-03.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/4718.2005-06-06.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/4013.2001-11-15.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/1174.2001-06-12.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/2351.2001-09-07.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/1121.2001-06-01.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/3002.2001-10-09.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/3429.2001-10-25.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/4501.2001-12-09.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/5191.2002-01-21.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/0588.2001-04-12.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/3523.2001-10-29.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/2513.2001-09-14.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/0757.2001-04-25.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/4522.2001-12-10.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/3021.2001-10-10.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/4681.2001-12-21.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/5247.2002-01-24.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/1995.2001-08-14.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/0797.2001-04-27.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/2678.2001-09-23.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/2704.2001-09-25.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/4119.2001-11-19.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/5058.2002-01-11.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/1087.2001-05-26.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/4791.2002-01-02.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/3791.2001-11-06.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/0932.2001-05-04.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/3496.2001-10-28.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/5192.2002-01-22.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/5055.2002-01-10.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/0273.2001-03-20.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/1871.2001-08-02.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/3150.2001-10-17.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/2993.2001-10-08.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/1213.2001-06-18.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/2893.2001-10-02.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/3857.2001-11-08.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/1506.2004-11-22.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/2129.2004-12-28.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/4673.2005-06-01.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/2463.2001-09-12.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/0130.2001-03-09.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/4302.2001-11-28.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/3386.2001-10-25.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/1999.2001-08-14.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/5094.2002-01-13.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/4646.2001-12-19.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/0009.2001-02-09.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/2708.2001-09-25.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/2803.2001-09-28.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/4115.2001-11-19.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/5486.2002-02-05.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/1822.2001-07-27.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/1588.2001-07-13.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/0207.2001-03-15.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/3610.2001-10-31.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/0055.2001-02-22.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/4781.2005-06-11.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/4180.2005-04-28.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/2711.2005-01-26.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/2916.2005-02-05.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/4470.2005-05-15.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/3622.2001-11-01.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/1548.2001-07-11.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/2213.2001-08-31.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/1008.2004-10-21.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/1426.2004-11-18.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/3828.2001-11-07.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/1992.2001-08-13.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/4828.2002-01-03.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/4201.2001-11-21.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/5424.2005-07-22.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/3901.2001-11-12.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/0880.2001-05-02.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/4520.2005-05-20.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/1124.2001-06-04.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/1396.2004-11-15.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/3030.2005-02-09.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/1756.2001-07-25.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/3894.2001-11-09.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/1158.2001-06-08.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/0456.2004-09-13.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/1937.2001-08-08.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/0242.2001-03-16.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/1619.2001-07-17.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/2117.2001-08-24.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/4345.2001-11-29.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/3460.2001-10-26.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/3667.2001-11-02.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/1970.2004-12-21.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/0714.2001-04-20.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/2738.2005-01-28.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/0494.2004-09-16.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/4198.2001-11-21.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/4441.2001-12-05.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/2384.2001-09-10.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/3117.2001-10-16.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/0316.2004-09-02.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/2814.2001-10-01.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/4481.2001-12-07.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/3145.2005-02-16.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/2694.2005-01-25.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/5072.2005-06-29.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/3308.2001-10-23.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/4728.2001-12-30.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/2068.2001-08-21.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/2890.2005-02-03.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/4024.2005-04-18.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/2453.2005-01-16.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/5307.2002-01-28.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/0004.2004-08-01.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/0136.2004-08-12.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/5207.2002-01-22.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/0109.2001-03-06.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/4366.2001-11-30.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/3947.2001-11-12.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/0076.2004-08-08.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/3233.2005-02-20.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/0834.2001-04-30.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/0615.2001-04-16.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/5412.2005-07-22.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/4729.2001-12-31.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/0808.2004-10-08.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/4567.2001-12-13.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/0619.2001-04-16.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/0838.2001-04-30.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/2556.2001-09-17.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/1250.2001-06-20.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/2316.2001-09-06.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/3273.2001-10-22.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/3725.2005-03-24.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/2262.2001-09-04.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/2065.2001-08-20.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/4283.2001-11-27.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/3983.2001-11-14.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/2012.2001-08-16.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/2577.2005-01-20.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/2966.2001-10-05.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/0820.2004-10-10.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/2954.2005-02-06.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/3546.2001-10-30.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/1938.2004-12-19.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/1547.2004-11-24.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/0812.2004-10-09.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/1679.2004-12-02.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/0386.2001-03-27.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/4741.2005-06-07.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/0610.2001-04-13.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/5406.2002-02-01.kitchen.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron103/4963.2002-01-08.kitchen.ham.txt
# ...
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron106/2756.2005-01-16.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron106/5916.2005-07-23.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron106/4702.2005-05-06.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron106/0429.2004-09-01.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron106/1886.2004-11-29.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron106/4391.2005-04-14.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron106/5295.2005-06-16.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron106/4473.2005-04-20.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron106/1224.2004-10-25.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron106/5192.2001-12-26.lokay.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron106/3111.2005-01-31.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron106/1746.2004-11-22.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron106/2480.2005-01-03.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron106/3635.2005-02-24.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron106/5044.2005-05-28.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron106/0873.2000-08-25.lokay.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron106/2530.2005-01-05.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron106/4663.2001-10-04.lokay.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron106/1119.2000-09-19.lokay.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron106/2627.2005-01-10.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron106/3139.2005-02-01.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron106/4124.2005-03-27.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron106/0167.2004-08-12.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron106/0771.2004-09-25.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron106/0096.2004-08-07.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron106/3432.2005-02-14.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron106/3850.2005-03-10.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron106/2615.2005-01-09.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron106/5957.2002-03-22.lokay.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron106/3716.2005-03-02.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron106/2300.2004-12-23.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron106/2441.2004-12-31.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron106/1168.2004-10-22.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron106/1039.2004-10-14.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron106/0021.2004-08-02.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron106/5438.2002-01-29.lokay.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron106/4216.2005-04-04.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron106/1784.2000-11-09.lokay.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron106/2545.2005-01-05.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron106/5843.2005-07-19.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron106/3275.2005-02-06.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron106/1732.2004-11-21.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron106/4414.2001-08-31.lokay.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron106/5740.2005-07-14.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron106/4576.2001-09-25.lokay.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron106/2900.2005-01-21.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron106/2692.2005-01-13.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron106/5696.2002-02-22.lokay.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron106/5588.2005-07-06.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron106/4777.2001-10-18.lokay.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron106/2901.2005-01-22.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron106/4519.2005-04-24.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron106/4718.2005-05-07.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron106/5211.2005-06-09.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron106/1405.2004-11-04.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron106/1317.2000-10-06.lokay.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron106/2640.2001-01-19.lokay.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron106/4618.2001-09-29.lokay.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron106/5223.2005-06-10.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron106/4762.2001-10-17.lokay.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron106/5134.2005-06-05.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron106/2787.2005-01-17.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron106/2402.2001-01-05.lokay.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron106/2507.2001-01-12.lokay.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron106/5826.2005-07-18.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron106/5054.2005-05-29.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron106/1857.2004-11-28.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron106/4533.2001-09-20.lokay.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron106/0177.2004-08-13.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron106/0761.2004-09-24.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron106/4048.2001-07-24.lokay.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron106/4383.2005-04-13.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron106/4967.2001-11-12.lokay.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron106/1266.2000-10-05.lokay.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron106/3572.2005-02-20.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron106/1162.2004-10-22.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron106/1363.2004-11-01.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron106/5727.2005-07-13.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron106/0220.2004-08-16.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron106/3211.2005-02-04.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron106/1284.2004-10-28.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron106/2129.2000-12-04.lokay.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron106/1095.2000-09-17.lokay.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron106/0044.2004-08-03.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron106/2416.2004-12-29.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron106/4790.2005-05-12.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron106/2964.2005-01-23.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron106/0564.2004-09-12.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron106/5906.2005-07-22.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron106/4431.2005-04-18.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron106/5229.2005-06-10.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron106/3420.2005-02-13.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron106/3030.2005-01-26.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron106/2161.2004-12-17.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron106/2450.2005-01-01.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron106/1776.2000-11-08.lokay.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron106/0850.2004-09-30.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron106/2879.2005-01-21.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron106/5617.2005-07-06.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron106/4660.2005-05-04.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron106/1590.2004-11-13.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron106/5290.2002-01-10.lokay.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron106/3980.2005-03-18.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron106/3771.2005-03-05.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron106/3081.2005-01-29.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron106/4970.2005-05-23.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron106/3186.2005-02-02.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron106/4176.2005-03-30.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron106/5247.2005-06-12.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron106/0538.2004-09-09.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron106/5649.2002-02-19.lokay.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron106/5747.2002-02-28.lokay.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron106/1086.2004-10-17.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron106/4855.2005-05-16.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron106/4691.2001-10-05.lokay.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron106/0646.2004-09-17.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron106/0629.2004-09-16.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron106/1852.2004-11-27.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron106/2312.2004-12-24.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron106/2682.2005-01-12.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron106/4567.2005-04-27.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron106/2863.2005-01-20.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron106/4304.2005-04-09.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron106/2115.2004-12-14.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron106/4229.2001-08-14.lokay.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron106/3864.2001-06-27.lokay.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron106/4336.2005-04-10.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron106/0717.2004-09-21.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron106/5790.2005-07-16.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron106/3650.2005-02-25.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron106/4022.2001-07-20.lokay.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron106/3438.2005-02-14.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron106/3457.2005-02-15.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron106/4268.2005-04-07.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron106/1517.2004-11-09.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron106/2065.2004-12-11.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron106/1722.2004-11-20.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron106/3316.2005-02-07.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron106/0935.2000-09-01.lokay.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron106/0277.2004-08-20.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron106/4247.2001-08-14.lokay.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron106/2263.2004-12-22.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron106/0031.2004-08-03.BG.spam.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron106/0359.2000-07-13.lokay.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron106/2743.2001-01-26.lokay.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron106/0663.2000-08-08.lokay.ham.txt
# /Users/zhouhaiqing/Downloads/Email-Classification-master/Enron Dataset/enron106/3395.2005-02-11.BG.spam.txt

# %% [markdown]
# ## 1. Import necessary libraries

# %%
import matplotlib.pyplot as plt
from gensim.models import KeyedVectors
from gensim.scripts.glove2word2vec import glove2word2vec
import time
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.models import Sequential

from keras.layers import Dense, LSTM, Flatten, Embedding
from keras.utils import to_categorical
from keras.backend import clear_session

# %% [markdown]
# ## 2. Load Pre-trained Embeddings

# %% [markdown]
# #### 2.1 Google's Word Embeddings

# %%
# load Google's pre-trained word2vec embeddings
filename = "/kaggle/input/googlenewsvectorsnegative300/GoogleNews-vectors-negative300.bin"

start = time.time()
google_embeddings = KeyedVectors.load_word2vec_format(filename, binary=True)

print("Load time (seconds): ", (time.time() - start))

# %% [markdown]
# #### 2.2 Stanford's Word Embeddings

# %%
# load Stanford's pre-trained GloVe embeddings
glove_file = "/kaggle/input/glove-embeddings/glove.6B.300d.txt"
glove_word2vec_file = "glove.6B.100d.txt.word2vec"

glove2word2vec(glove_file, glove_word2vec_file)

# %%
# glove embeddings
start = time.time()

glove_embeddings = KeyedVectors.load_word2vec_format(glove_word2vec_file, binary=False)

print("Load time (seconds): ", (time.time() - start))

# %% [markdown]
# ## 3. Load Data

# %%
# load data
data = pd.read_csv("/kaggle/input/enron-email-classification-using-machine-learning/preprocessed.csv")

# view first 5 rows of the dataframe 'data'
data.head()

# %% [markdown]
# ## 4. Prepare Data

# %%
# shape of the data
data.shape

# %% [markdown]
# #### 4.1 Encode class labels

# %%
# count number of instances in each folder
data['X-Folder'].unique()

# %%
def label_encoder(data):
    class_le = LabelEncoder()
    # apply label encoder on the 'X-Folder' column
    y = class_le.fit_transform(data['X-Folder'])
    return y

# %%
y = label_encoder(data)
input_data = data['text']

# %%
# split the data into training and test set
X_train, X_test, y_train, y_test = train_test_split(input_data, y, test_size=0.1)

# %%
# one-hot encode the output labels
Y_train = to_categorical(y_train, 20)
Y_test = to_categorical(y_test, 20)

# %%
# prepare tokenizer
t = Tokenizer()

# fit the tokenizer on the docs
t.fit_on_texts(input_data)
vocab_size = len(t.word_index) + 1

# integer encode the documents
X_train_encoded_docs = t.texts_to_sequences(X_train)
X_test_encoded_docs = t.texts_to_sequences(X_test)

# %%
# pad documents to a max length of 150 words
max_length = 150
X_train_padded_docs = pad_sequences(X_train_encoded_docs, maxlen=max_length, padding='post')
X_test_padded_docs = pad_sequences(X_test_encoded_docs, maxlen=max_length, padding='post')

print(X_train_padded_docs[0])

# %% [markdown]
# ## 5. Using Google's Pre-trained Word Embeddings

# %%
# create a weight matrix for words in training docs
embedding_matrix = np.zeros((vocab_size, 300))

for word, i in t.word_index.items():
    
    try:
        embedding_vector = google_embeddings[word]
    
        if embedding_vector is not None:
            embedding_matrix[i] = embedding_vector 
    except:
        pass

# %%
# define the model
model = Sequential()
e = Embedding(vocab_size, 300, weights=[embedding_matrix], input_length=max_length, trainable=False)
model.add(e)
model.add(LSTM(100, dropout=0.2))
model.add(Flatten())
model.add(Dense(20, activation='softmax'))


# compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# summarize the model
model.summary()

# %%
clear_session()

# %%
# train the model
clear_session()
history = model.fit(X_train_padded_docs, Y_train, epochs=60, verbose=1, validation_split=0.1)

# %%
# evaluate the model on the test set
accr = model.evaluate(X_test_padded_docs, Y_test)
print("Test Set: \n Loss: {:0.3f}\n Accuracy: {:0.3f}".format(accr[0], accr[1]))

# %%
# plot the loss
plt.title("Word2Vec Loss")
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='validation')
plt.legend()
plt.show()

# %%
# plot the accuracy
plt.title("Word2Vec Accuracy")
plt.plot(history.history['accuracy'], label='train')
plt.plot(history.history['val_accuracy'], label='validation')
plt.legend()
plt.xlabel('Epochs')
plt.ylabel("Accuracy")
plt.show()

# %% [markdown]
# ## 6. Using GloVe Word Embeddings

# %%
# create a weight matrix for words in training docs
embedding_matrix = np.zeros((vocab_size, 300))

for word, i in t.word_index.items():
    
    try:
        embedding_vector = glove_embeddings[word]
    
        if embedding_vector is not None:
            embedding_matrix[i] = embedding_vector 
    except:
        pass

# %%
# define the model
model2 = Sequential()
e = Embedding(vocab_size, 300, weights=[embedding_matrix], input_length=max_length, trainable=False)
model2.add(e)
model2.add(LSTM(100, dropout=0.2))
model2.add(Flatten())
model2.add(Dense(20, activation='softmax'))


# compile the model
model2.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# summarize the model
model2.summary()

# %%
# fit the model
history2 = model2.fit(X_train_padded_docs, Y_train, epochs=60, verbose=1, validation_split=0.1)

# %%
# evaluate the model2 on the test set
accr2 = model2.evaluate(X_test_padded_docs, Y_test)
print("Test Set: \n Loss: {:0.3f}\n Accuracy: {:0.3f}".format(accr2[0], accr2[1]))

# %%
# plot the loss
plt.title("Glove Word2Vec Loss")
plt.plot(history2.history['loss'], label='train')
plt.plot(history2.history['val_loss'], label='validation')
plt.legend()
plt.xlabel("Epochs")
plt.ylabel("loss")
plt.show()

# %%
# plot the accuracy
plt.title("GloVe Word2Vec Accuracy")
plt.plot(history2.history['accuracy'], label='train')
plt.plot(history2.history['val_accuracy'], label='validation')
plt.legend()
plt.xlabel('Epochs')
plt.ylabel("Accuracy")
plt.show()

# %% [markdown]
# ## 7. Word Embeddings using Training Data

# %%
# define the model
model3 = Sequential()
model3.add(Embedding(vocab_size, 300, input_length=max_length))
model3.add(LSTM(100, dropout=0.4))
model3.add(Flatten())
model3.add(Dense(20, activation='softmax'))

# compile the model
model3.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# summarize the model
model3.summary()

# %%
# train the model
history3 = model3.fit(X_train_padded_docs, Y_train, validation_split=0.1, epochs=20, verbose=1)

# %%
# save learned word embeddings
own_embeddings = model3.get_layer('embedding_2').get_weights()[0]

custom_w2v = {}

for word, index in t.word_index.items():
    custom_w2v[word] = own_embeddings[index]
    
import pickle    
# save to file
with open("own_embeddings.pkl", "wb") as handle:
    pickle.dump(custom_w2v, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
# load own_embeddings
#with open("own_embeddings.pkl", "rb") as handle:
 #   own_embeddings = pickle.load(handle)

# %%
# evaluate the model
accr3 = model3.evaluate(X_test_padded_docs, Y_test)

print("Test Set:\n  Loss: {:0.3f}\n   Accuracy: {:0.3f}".format(accr3[0], accr3[1]))

# %%
# plot the loss
plt.title("Loss")
plt.plot(history3.history['loss'], label='train')
plt.plot(history3.history['val_loss'], label='validation')
plt.legend()
plt.xlabel("Epochs")
plt.ylabel("loss")
plt.show()

# %%
# plot the accuracy
plt.title("Accuracy")
plt.plot(history3.history['accuracy'], label='train')
plt.plot(history3.history['val_accuracy'], label='validation')
plt.legend()
plt.xlabel('Epochs')
plt.ylabel("Accuracy")
plt.show()

# %% [markdown]
# ## 8. Results

# %%
# create a dataframe to store results
res_data = {
    "Technique": ['Word2Vec', 'GloVe', 'Training data Embeddings'],
    "test accuracy": [accr[1], accr2[1], accr3[1]]
}
result = pd.DataFrame(res_data)
result

# %% [markdown]
# - **Word2Vec:** Google's pre-trained word embeddings Google news data (about 100 billion words).
# - **GloVe:** Stanford's pre-trained word embeddings trained on Wikipedia data with 6 billion tokens and a 400,000 word vocabulary.
# -  **Training data Embeddings:** Embeddings learned from training data
# - LSTM with one hidden layer and 100 units has been trained to classify folders based on these word embeddings.

# %%
data.shape
